# %% [markdown]
# ## Import Packages

# %%
import map;

# %%
import extract;

# %%
import line;

# %%
import process;

# %%
import predict;

# %% [markdown]
# ## Statement

# %%
let data := "/data";

# %%
let data1 := "data/";

# %%
extract();

# %% [markdown]
# ## Data description

# %%
draw_line(data,data);

# %%
print("file:///data/line.png");

# %%
create_map(data,data);

# %%
print("file:///data/map.png");

# %% [markdown]
# ## Data Preprocessing

# %%
create_train_dateset(data1);

# %%
create_test_dateset(data1);

# %% [markdown]
# ## Model

# %%
run_LR(data,data);

# %%
final_result(data,data);

# %% [markdown]
# ## Visualization

# %%
draw_pre(data,data);

# %%
print("file:///data/prediction.png");
